# %%
import omop_alchemy as oa
from omop_alchemy.db import Base, engine

import sqlalchemy as sa
import sqlalchemy.orm as so

from omop_alchemy.tables.clinical import Person, Condition_Occurrence, Condition_Modifier, Measurement

# %%
with so.Session(engine) as sess:
    conds = sess.query(Condition_Occurrence).options(so.joinedload(Condition_Occurrence.modifiers,
                                                      Measurement.measurement_concept)).all()
# Out:
# 2024-02-06 20:39:17,219 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-02-06 20:39:17,221 INFO sqlalchemy.engine.Engine SELECT condition_occurrence.condition_occurrence_id AS condition_occurrence_condition_occurrence_id, condition_occurrence.condition_start_date AS condition_occurrence_condition_start_date, condition_occurrence.condition_start_datetime AS condition_occurrence_condition_start_datetime, condition_occurrence.condition_end_date AS condition_occurrence_condition_end_date, condition_occurrence.condition_end_datetime AS condition_occurrence_condition_end_datetime, condition_occurrence.stop_reason AS condition_occurrence_stop_reason, condition_occurrence.condition_source_value AS condition_occurrence_condition_source_value, condition_occurrence.condition_status_source_value AS condition_occurrence_condition_status_source_value, condition_occurrence.person_id AS condition_occurrence_person_id, condition_occurrence.provider_id AS condition_occurrence_provider_id, condition_occurrence.visit_occurrence_id AS condition_occurrence_visit_occurrence_id, condition_occurrence.visit_detail_id AS condition_occurrence_visit_detail_id, condition_occurrence.condition_concept_id AS condition_occurrence_condition_concept_id, condition_occurrence.condition_type_concept_id AS condition_occurrence_condition_type_concept_id, condition_occurrence.condition_status_concept_id AS condition_occurrence_condition_status_concept_id, condition_occurrence.condition_source_concept_id AS condition_occurrence_condition_source_concept_id
# FROM condition_occurrence
# 2024-02-06 20:39:17,221 INFO sqlalchemy.engine.Engine [cached since 1318s ago] ()
# 2024-02-06 20:39:17,223 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
with so.Session(engine) as sess:
    conds = sess.query(Condition_Occurrence).all()
# Out:
# 2024-02-06 17:07:28,451 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-02-06 17:07:28,452 INFO sqlalchemy.engine.Engine SELECT condition_occurrence.condition_occurrence_id AS condition_occurrence_condition_occurrence_id, condition_occurrence.condition_start_date AS condition_occurrence_condition_start_date, condition_occurrence.condition_start_datetime AS condition_occurrence_condition_start_datetime, condition_occurrence.condition_end_date AS condition_occurrence_condition_end_date, condition_occurrence.condition_end_datetime AS condition_occurrence_condition_end_datetime, condition_occurrence.stop_reason AS condition_occurrence_stop_reason, condition_occurrence.condition_source_value AS condition_occurrence_condition_source_value, condition_occurrence.condition_status_source_value AS condition_occurrence_condition_status_source_value, condition_occurrence.person_id AS condition_occurrence_person_id, condition_occurrence.provider_id AS condition_occurrence_provider_id, condition_occurrence.visit_occurrence_id AS condition_occurrence_visit_occurrence_id, condition_occurrence.visit_detail_id AS condition_occurrence_visit_detail_id, condition_occurrence.condition_concept_id AS condition_occurrence_condition_concept_id, condition_occurrence.condition_type_concept_id AS condition_occurrence_condition_type_concept_id, condition_occurrence.condition_status_concept_id AS condition_occurrence_condition_status_concept_id, condition_occurrence.condition_source_concept_id AS condition_occurrence_condition_source_concept_id
# FROM condition_occurrence
# 2024-02-06 17:07:28,454 INFO sqlalchemy.engine.Engine [generated in 0.00136s] ()
# 2024-02-06 17:07:28,454 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
conds
# Out:
# []

# %%
with so.Session(engine) as sess:
    people = sess.query(Person).options(so.joinedload(Person.conditions, 
                                                      Condition_Occurrence.condition_concept,
                                                      Condition_Modifier.measurement_concept)).all()
# Out:
# 2024-02-06 20:39:26,392 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-02-06 20:39:26,394 INFO sqlalchemy.engine.Engine ROLLBACK
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In[8], line 5
#       1 with so.Session(engine) as sess:
#       2     people = sess.query(Person).options(so.joinedload(Person.conditions,
#       3                                                       Condition_Occurrence.condition_concept)
#       4                               ).options(so.joinedload(Condition_Occurrence.modifiers,
# ----> 5                                                       Condition_Modifier.measurement_concept)).all()
#
# File ~/Documents/ingham/CODE/OMOP_Alchemy/.venv/lib/python3.11/site-packages/sqlalchemy/orm/query.py:2693, in Query.all(self)
#    2671 def all(self) -> List[_T]:
#    2672     """Return the results represented by this :class:`_query.Query`
#    2673     as a list.
#    2674
#    (...)
#    2691         :meth:`_engine.Result.scalars` - v2 comparable method.
#    2692     """
# -> 2693     return self._iter().all()
#
# File ~/Documents/ingham/CODE/OMOP_Alchemy/.venv/lib/python3.11/site-packages/sqlalchemy/orm/query.py:2847, in Query._iter(self)
#    2844 params = self._params
#    2846 statement = self._statement_20()
# -> 2847 result: Union[ScalarResult[_T], Result[_T]] = self.session.execute(
#    2848     statement,
#    2849     params,
#    2850     execution_options={"_sa_orm_load_options": self.load_options},
#    2851 )
#    2853 # legacy: automatically set scalars, unique
#    2854 if result._attributes.get("is_single_entity", False):
#
# File ~/Documents/ingham/CODE/OMOP_Alchemy/.venv/lib/python3.11/site-packages/sqlalchemy/orm/session.py:2308, in Session.execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event)
#    2247 def execute(
#    2248     self,
#    2249     statement: Executable,
#    (...)
#    2255     _add_event: Optional[Any] = None,
#    2256 ) -> Result[Any]:
#    2257     r"""Execute a SQL expression construct.
#    2258
#    2259     Returns a :class:`_engine.Result` object representing
#    (...)
#    2306
#    2307     """
# -> 2308     return self._execute_internal(
#    2309         statement,
#    2310         params,
#    2311         execution_options=execution_options,
#    2312         bind_arguments=bind_arguments,
#    2313         _parent_execute_state=_parent_execute_state,
#    2314         _add_event=_add_event,
#    2315     )
#
# File ~/Documents/ingham/CODE/OMOP_Alchemy/.venv/lib/python3.11/site-packages/sqlalchemy/orm/session.py:2190, in Session._execute_internal(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, _scalar_result)
#    2185     return conn.scalar(
#    2186         statement, params or {}, execution_options=execution_options
#    2187     )
#    2189 if compile_state_cls:
# -> 2190     result: Result[Any] = compile_state_cls.orm_execute_statement(
#    2191         self,
#    2192         statement,
#    2193         params or {},
#    2194         execution_options,
#    2195         bind_arguments,
#    2196         conn,
#    2197     )
#    2198 else:
#    2199     result = conn.execute(
#    2200         statement, params or {}, execution_options=execution_options
#    2201     )
#
# File ~/Documents/ingham/CODE/OMOP_Alchemy/.venv/lib/python3.11/site-packages/sqlalchemy/orm/context.py:293, in AbstractORMCompileState.orm_execute_statement(cls, session, statement, params, execution_options, bind_arguments, conn)
#     283 @classmethod
#     284 def orm_execute_statement(
#     285     cls,
#    (...)
#     291     conn,
#     292 ) -> Result:
# --> 293     result = conn.execute(
#     294         statement, params or {}, execution_options=execution_options
#     295     )
#     296     return cls.orm_setup_cursor_result(
#     297         session,
#     298         statement,
#    (...)
#     302         result,
#     303     )
#
# File ~/Documents/ingham/CODE/OMOP_Alchemy/.venv/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File ~/Documents/ingham/CODE/OMOP_Alchemy/.venv/lib/python3.11/site-packages/sqlalchemy/sql/elements.py:517, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     515     if TYPE_CHECKING:
#     516         assert isinstance(self, Executable)
# --> 517     return connection._execute_clauseelement(
#     518         self, distilled_params, execution_options
#     519     )
#     520 else:
#     521     raise exc.ObjectNotExecutableError(self)
#
# File ~/Documents/ingham/CODE/OMOP_Alchemy/.venv/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1631, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1623 schema_translate_map = execution_options.get(
#    1624     "schema_translate_map", None
#    1625 )
#    1627 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1628     "compiled_cache", self.engine._compiled_cache
#    1629 )
# -> 1631 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1632     dialect=dialect,
#    1633     compiled_cache=compiled_cache,
#    1634     column_keys=keys,
#    1635     for_executemany=for_executemany,
#    1636     schema_translate_map=schema_translate_map,
#    1637     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1638 )
#    1639 ret = self._execute_context(
#    1640     dialect,
#    1641     dialect.execution_ctx_cls._init_compiled,
#    (...)
#    1649     cache_hit=cache_hit,
#    1650 )
#    1651 if has_events:
#
# File ~/Documents/ingham/CODE/OMOP_Alchemy/.venv/lib/python3.11/site-packages/sqlalchemy/sql/elements.py:705, in ClauseElement._compile_w_cache(self, dialect, compiled_cache, column_keys, for_executemany, schema_translate_map, **kw)
#     703 if compiled_sql is None:
#     704     cache_hit = dialect.CACHE_MISS
# --> 705     compiled_sql = self._compiler(
#     706         dialect,
#     707         cache_key=elem_cache_key,
#     708         column_keys=column_keys,
#     709         for_executemany=for_executemany,
#     710         schema_translate_map=schema_translate_map,
#     711         **kw,
#     712     )
#     713     compiled_cache[key] = compiled_sql
#     714 else:
#
# File ~/Documents/ingham/CODE/OMOP_Alchemy/.venv/lib/python3.11/site-packages/sqlalchemy/sql/elements.py:317, in CompilerElement._compiler(self, dialect, **kw)
#     315 if TYPE_CHECKING:
#     316     assert isinstance(self, ClauseElement)
# --> 317 return dialect.statement_compiler(dialect, self, **kw)
#
# File ~/Documents/ingham/CODE/OMOP_Alchemy/.venv/lib/python3.11/site-packages/sqlalchemy/sql/compiler.py:1427, in SQLCompiler.__init__(self, dialect, statement, cache_key, column_keys, for_executemany, linting, _supporting_against, **kwargs)
#    1424 self.truncated_names: Dict[Tuple[str, str], str] = {}
#    1425 self._truncated_counters: Dict[str, int] = {}
# -> 1427 Compiled.__init__(self, dialect, statement, **kwargs)
#    1429 if self.isinsert or self.isupdate or self.isdelete:
#    1430     if TYPE_CHECKING:
#
# File ~/Documents/ingham/CODE/OMOP_Alchemy/.venv/lib/python3.11/site-packages/sqlalchemy/sql/compiler.py:867, in Compiled.__init__(self, dialect, statement, schema_translate_map, render_schema_translate, compile_kwargs)
#     865         assert isinstance(statement, Executable)
#     866     self.execution_options = statement._execution_options
# --> 867 self.string = self.process(self.statement, **compile_kwargs)
#     869 if render_schema_translate:
#     870     self.string = self.preparer._render_schema_translates(
#     871         self.string, schema_translate_map
#     872     )
#
# File ~/Documents/ingham/CODE/OMOP_Alchemy/.venv/lib/python3.11/site-packages/sqlalchemy/sql/compiler.py:912, in Compiled.process(self, obj, **kwargs)
#     911 def process(self, obj: Visitable, **kwargs: Any) -> str:
# --> 912     return obj._compiler_dispatch(self, **kwargs)
#
# File ~/Documents/ingham/CODE/OMOP_Alchemy/.venv/lib/python3.11/site-packages/sqlalchemy/sql/visitors.py:143, in Visitable._generate_compiler_dispatch.<locals>._compiler_dispatch(self, visitor, **kw)
#     141     return visitor.visit_unsupported_compilation(self, err, **kw)  # type: ignore  # noqa: E501
#     142 else:
# --> 143     return meth(self, **kw)
#
# File ~/Documents/ingham/CODE/OMOP_Alchemy/.venv/lib/python3.11/site-packages/sqlalchemy/sql/compiler.py:4609, in SQLCompiler.visit_select(self, select_stmt, asfrom, insert_into, fromhints, compound_index, select_wraps_for, lateral, from_linter, **kwargs)
#    4601 # initial setup of SELECT.  the compile_state_factory may now
#    4602 # be creating a totally different SELECT from the one that was
#    4603 # passed in.  for ORM use this will convert from an ORM-state
#    4604 # SELECT to a regular "Core" SELECT.  other composed operations
#    4605 # such as computation of joins will be performed.
#    4607 kwargs["within_columns_clause"] = False
# -> 4609 compile_state = select_stmt._compile_state_factory(
#    4610     select_stmt, self, **kwargs
#    4611 )
#    4612 kwargs[
#    4613     "ambiguous_table_name_map"
#    4614 ] = compile_state._ambiguous_table_name_map
#    4616 select_stmt = compile_state.statement
#
# File ~/Documents/ingham/CODE/OMOP_Alchemy/.venv/lib/python3.11/site-packages/sqlalchemy/sql/base.py:687, in CompileState.create_for_statement(cls, statement, compiler, **kw)
#     685     return cls(statement, compiler, **kw)
#     686 else:
# --> 687     return klass.create_for_statement(statement, compiler, **kw)
#
# File ~/Documents/ingham/CODE/OMOP_Alchemy/.venv/lib/python3.11/site-packages/sqlalchemy/orm/context.py:1131, in ORMSelectCompileState.create_for_statement(cls, statement, compiler, **kw)
#    1129     for opt in self.select_statement._with_options:
#    1130         if opt._is_compile_state:
# -> 1131             opt.process_compile_state(self)
#    1133 # uncomment to print out the context.attributes structure
#    1134 # after it's been set up above
#    1135 # self._dump_option_struct()
#    1137 if select_statement._with_context_options:
#
# File ~/Documents/ingham/CODE/OMOP_Alchemy/.venv/lib/python3.11/site-packages/sqlalchemy/orm/strategy_options.py:915, in _AbstractLoad.process_compile_state(self, compile_state)
#     912 if not compile_state.compile_options._enable_eagerloads:
#     913     return
# --> 915 self._process(
#     916     compile_state,
#     917     compile_state._lead_mapper_entities,
#     918     not bool(compile_state.current_path)
#     919     and not compile_state.compile_options._for_refresh_state,
#     920 )
#
# File ~/Documents/ingham/CODE/OMOP_Alchemy/.venv/lib/python3.11/site-packages/sqlalchemy/orm/strategy_options.py:1125, in Load._process(self, compile_state, mapper_entities, raiseerr)
#    1120 reconciled_lead_entity = self._reconcile_query_entities_with_us(
#    1121     mapper_entities, raiseerr
#    1122 )
#    1124 for loader in self.context:
# -> 1125     loader.process_compile_state(
#    1126         self,
#    1127         compile_state,
#    1128         mapper_entities,
#    1129         reconciled_lead_entity,
#    1130         raiseerr,
#    1131     )
#
# File ~/Documents/ingham/CODE/OMOP_Alchemy/.venv/lib/python3.11/site-packages/sqlalchemy/orm/strategy_options.py:1697, in _LoadElement.process_compile_state(self, parent_loader, compile_state, mapper_entities, reconciled_lead_entity, raiseerr)
#    1685 def process_compile_state(
#    1686     self,
#    1687     parent_loader,
#    (...)
#    1691     raiseerr,
#    1692 ):
#    1693     """populate ORMCompileState.attributes with loader state for this
#    1694     _LoadElement.
#    1695
#    1696     """
# -> 1697     keys = self._prepare_for_compile_state(
#    1698         parent_loader,
#    1699         compile_state,
#    1700         mapper_entities,
#    1701         reconciled_lead_entity,
#    1702         raiseerr,
#    1703     )
#    1704     for key in keys:
#    1705         if key in compile_state.attributes:
#
# File ~/Documents/ingham/CODE/OMOP_Alchemy/.venv/lib/python3.11/site-packages/sqlalchemy/orm/strategy_options.py:2057, in _AttributeStrategyLoad._prepare_for_compile_state(self, parent_loader, compile_state, mapper_entities, reconciled_lead_entity, raiseerr)
#    2054     return []
#    2056 if raiseerr and not reconciled_lead_entity:
# -> 2057     self._raise_for_no_match(parent_loader, mapper_entities)
#    2059 if self.path.has_entity:
#    2060     effective_path = self.path.parent
#
# File ~/Documents/ingham/CODE/OMOP_Alchemy/.venv/lib/python3.11/site-packages/sqlalchemy/orm/strategy_options.py:1611, in _LoadElement._raise_for_no_match(self, parent_loader, mapper_entities)
#    1605     raise sa_exc.ArgumentError(
#    1606         "Query has only expression-based entities; "
#    1607         f"attribute loader options for {path[0]} can't "
#    1608         "be applied here."
#    1609     )
#    1610 else:
# -> 1611     raise sa_exc.ArgumentError(
#    1612         f"Mapped class {path[0]} does not apply to any of the "
#    1613         f"root entities in this query, e.g. "
#    1614         f"""{
#    1615             ", ".join(
#    1616                 str(x.entity_zero)
#    1617                 for x in mapper_entities if x.entity_zero
#    1618             )}. Please """
#    1619         "specify the full path "
#    1620         "from one of the root entities to the target "
#    1621         "attribute. "
#    1622     )
#
# ArgumentError: Mapped class Mapper[Condition_Occurrence(condition_occurrence)] does not apply to any of the root entities in this query, e.g. Mapper[Person(person)]. Please specify the full path from one of the root entities to the target attribute.
